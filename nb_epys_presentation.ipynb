# %% [markdown]
# # e[PY]s: A Python Library for SciOps Analysis

# %% [markdown]
# ## Define a few support things...

# %% [markdown]
# Grab my system username.

# %%
user_name = !whoami
user_name = user_name[0]

# %% [markdown]
# The following autoreloads packages and sub-packages before each call. This removes the need to restart the kernel after each change to the packages, in particular to epys.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Enable access to bash profile aliases

# %%
# %%bash
# . ~/.bash_profile

# %% [markdown]
# We may want to display some webpages in the notebook...

# %%
from IPython.display import HTML, SVG
from IPython import display

# %% [markdown]
# We can add widgets for interactivity

# %%
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets

# %% [markdown]
# Set Matplotlib plot size

# %%
import matplotlib as mpl

# %%
mpl.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# ##  e[PY]s

# %% [markdown]
# What it says on the tin:
# <blockquote>
# "ePYs is a python library for the creation, manipulation, processing and plotting of the input and output files of ESA's Experiment Planning Software (EPS).
# </blockquote>

# %% [markdown]
# It's a "pulling-together" of many bits 'n' pieces of code I've written over the past 3 years or so...

# %% [markdown]
# The package can be installed directly from <a href="https://pypi.python.org/pypi/epys/">PyPi</a>. And the project is hosted on <a href='https://github.com/johnnycakes79/epys'>GitHub</a> with documenation on <a href="http://epys.rtfd.org.">ReadTheDocs</a>.
#
# It uses <a href="https://travis-ci.org/johnnycakes79/epys">Travis CI</a> for continuous integration and <a href="https://coveralls.io/r/johnnycakes79/epys">Coveralls</a> for test coverage checking... this is pretty low at the moment.

# %% [markdown]
# It's functionality is spread across 6 modules, but what I will present here comes mainly from the <strong>read</strong> and <strong>utils</strong> modules.
# <ul>
# <li>
# <strong>draw</strong> makes pretty orbit graphics</li>
# <li>
# <strong>events</strong> provides a series of time/date utilities</li>
# <li>
# <strong>maps</strong> does things with maps and images</li>
# <li>
# <strong>orbit</strong> processes mission analysis orbit files</li>
# <li>
# <strong>read</strong> reads EPS/MAPPS output into useable dataframes and/or arrays</li>
# <li>
# <strong>utils</strong> more utilities ...</li>
# </ul>

# %%
HTML('<iframe src=http://johnnycakes79.github.io/epys/ width=100% height=640></iframe>')
# Out:
# <iframe src=http://johnnycakes79.github.io/epys/ width=100% height=640></iframe>

# %% [markdown]
# <img style="" src="http://nbviewer.ipython.org/github/ipython/ipython/blob/master/examples/images/ipython_logo.png">

# %% [markdown]
# ## IPython

# %% [markdown]
# IPython provides extensions to the Python programming language that make working interactively convenient and efficient.
#
# These extensions are implemented in the IPython Kernel and are available in all of the IPython Frontends (Notebook, Terminal, Console and Qt Console) when running this kernel.

# %% [markdown]
# ## IPython Notebook

# %% [markdown]
# The IPython Notebook is a web-based interactive computing system that enables users to author documents that include live code, narrative text, LaTeX equations, HTML, images and video.
#
# These documents are contain a full record of a computation and its results and can be shared on email, [Dropbox](http://dropbox.com), version control systems (like git/[GitHub](http://github.com)) or [nbviewer.ipython.org](http://nbviewer.ipython.org).
#
# It's interactive documentation ... for free!

# %% [markdown]
# ## Initial Import

# %%
import epys # pronounce e-pie-s

# %% [markdown]
# ### Standard Library Packages used in this demo

# %% [markdown]
# <p>The <b><a href="https://docs.python.org/2/library/pickle.html">cPickle</a></b> module supports serialization and de-serialization of Python objects, providing an interface and functionality nearly identical to the pickle module. </p>

# %%
import cPickle as pickle

# %% [markdown]
# <p>The <b><a class="reference internal" href="https://docs.python.org/2/library/datetime.html?highlight=datetime#module-datetime" title="datetime: Basic date and time types."><tt class="xref py py-mod docutils literal"><span class="pre"><span class="highlighted">datetime</span></span></tt></a></b> module supplies classes for manipulating dates and times in both simple and complex ways.</p>

# %%
from datetime import datetime as dt

# %% [markdown]
# ## Heavy Lifting

# %% [markdown]
# <p><b><a href="http://pandas.pydata.org/">Pandas</a></b> is a software library written for the <b>Python</b> programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and <b>time series</b>.</p>

# %%
import pandas as pd

# %% [markdown]
# Increase dataframe max width and height

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# <p><b><a href="http://www.numpy.org/">NumPy</a></b> is an extension adding support for large, multi-dimensional arrays and matrices, along with a large library of high-level mathematical functions to operate on these arrays. </p>

# %%
import numpy as np

# %% [markdown]
# <b><a href="https://plot.ly/">Plotly</a></b> is an online analytics and data visualization tool, providing online graphing, analytics, a Python command line, and stats tools for individuals and collaboration, as well as scientific graphing libraries for Python, R, MATLAB, Perl, Julia, Arduino, and REST.

# %%
import plotly.plotly as py

# %%
import plotly.tools as tls
from plotly.graph_objs import Data, Layout, Figure, XAxis, YAxis, Scatter, Line, Legend

# %% [markdown]
# Setup plotly sign-in in ~/.plotly/.credentials ... <a href="http://nbviewer.ipython.org/github/plotly/python-user-guide/blob/master/s00_homepage/s00_homepage.ipynb#Step-6">see the Plot.ly API Users Guide Step 6</a>.

# %% [markdown]
# ## EPS Simulation

# %% [markdown]
# The IPython Notebook has direct access to the command line and so EPS can be executed from within the notebook.
#
# This is handy - we can set the simluation parameters from within the notebook as well as capture and parse the output.

# %%
import os

# %%
simulation_tag = "P1A-P2B-P3C-P4D"
study_directory = '/Users/jmcaulif/Code/bepic/DATA'
output_directory = "/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA"
itl =  study_directory + "/ITL/" + "BC_SOA2013_" + simulation_tag + ".itl"
evf = study_directory + "/OGS/" + "BC_SOA2013_" + simulation_tag + ".evf"
infofile = "simulation_info"
epscfg = study_directory + "/CONFIG/" + "eps_mac.cfg"

# build up the output directory name
nowtag = dt.today().strftime("%Y%m%d_%H%M%S")
output_directory_name = '{}_{}'.format(nowtag, simulation_tag)
output_directory = os.path.join(output_directory, output_directory_name)

# define the time steps to use for sim and output
sim_tstep = 3600
output_tstep = 86400

# %%
# run eps ...
# !eps exec -i $itl -c $epscfg -er all -ei $evf -m -s $output_tstep -t $sim_tstep -ed "$output_directory"
# Out:
# Loading EDF file: bepi.edf
# Loading ITL file: /Users/jmcaulif/Code/bepic/DATA/ITL/BC_SOA2013_P1A-P2B-P3C-P4D.itl
# Loading EVF file: /Users/jmcaulif/Code/bepic/DATA/OGS/BC_SOA2013_P1A-P2B-P3C-P4D.evf
# Initialising the TimelineExecutor...
# Simulation start time: 7-May-2024_00:00:00
# Simulation end time:   7-May-2025_00:00:00
# Simulation step size:  3600 [seconds] (8761 steps)
# Reporting step size:   86400 [seconds] (366 steps)
# Running the input timeline...
# 0%
# .
# ..
# .
# 10%.
# ..
# .
# 20%
# .
# .
# .
# .
# 30%
# .
# .
# .
# .40%
# .
# .
# .
# .
# 50%
# .
# .
# .
# EventHandler: Warning: Input event set to same state MPO_ALT_BELOW_1050_PERH_START
#    Info: At event time 1-December-2024_19:10:20
# EventHandler: Warning: Input event set to same state MPO_ALT_BELOW_800_PERH_START
#    Info: At event time 1-December-2024_20:37:20
# EventHandler: Warning: Input event set to same state MPO_ALT_BELOW_600_PERH_START
#    Info: At event time 1-December-2024_20:45:10
# .60%
# .
# .
# .
# .
# 70%
# .
# .
# ..
# 80%
# .
# ..
# .
# 90%
# .
# .
# .
# .
# 100%
# EPS: 458 conflicts detected during execution

# %% [markdown]
# We define a few data sets to quickly switch between studies.

# %%
study = 'current'

if study == 'small':
    power_avg_file = '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/20140820_135128_AllOn/power_avg.out' # small
    data_rate_avg_file = '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/20140820_135128_AllOn/data_rate_avg.out' # small

if study == 'big':
    power_avg_file = '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/20140813_144028_OptB/power_avg.out' # big
    data_rate_avg_file = '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/20140813_144028_OptB/data_rate_avg.out' # big
    
if study == 'current':
    power_avg_file = output_directory + '/power_avg.out' # current
    data_rate_avg_file = output_directory + '/data_rate_avg.out' # current

power_budget_file= study_directory + '/OGS/pwr_bdg_bepi_mpo_0004b.pwr'
downlink_budget_file= study_directory + '/OGS/ddl_est_bepi_mpo_so10_0001.brf'

mapps_datapack_file = '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/mapps_datapack.csv'

# %% [markdown]
# The 'small', 'big' and 'current' study-flags allow me to switch rapidly between simulations with a large timestep (small file size) or a small timestep (large file size) - and with the latest simulation run (current) executed above.

# %% [markdown]
# ## Power Analysis

# %% [markdown]
# <p><b>epys</b> defines a number of table classes to deal with the main EPS/MAPPS input and output data formats, such as power and data downlink budgets and power usage and data production output files.</p>
#
# <p>The base class of these tables is the <b>epstable</b> from which 2 more specific table classes are sub-classed: <b>powertable</b> and <b>datatable</b>. </p>

# %% [markdown]
# <p>Help is available within IPython or the IPython Notebook environment. </p>

# %%
help(epys.epstable)

# %% [markdown]
# The docmentation is built into the code itself...

# %%
class epstable:
    """
    This is the base class for data tables in epys. Upon instantiation it is
    provided with a filename which is read into a header dictionary and a
    Pandas dataframe. The class has a number of methods for querying its
    characteristics, plotting its contents and merging other tables into it.
    """
    def __init__(self, fname, columns=False):
        """
        This constructor method initialises the epstable object.

        :param fname: input filename
        :type fname: str
        :param columns: user supplied list of column headings
        :type columns: list or tuple
        :returns: epstable object consisting of a header dictionary and Pandas dataframe
        """
        self.data, self.header = read(fname, meta=True, columns=columns)

# %% [markdown]
# And pretty docs are auto-generated and made available online: <a href=http://epys.readthedocs.org/en/latest/index.html><b>readthedocs</b></a>.

# %%
HTML('<iframe src=http://epys.readthedocs.org/en/latest/index.html width=100% height=500></iframe>')
# Out:
# <iframe src=http://epys.readthedocs.org/en/latest/index.html width=100% height=500></iframe>

# %% [markdown]
# ### So let's read-in some data

# %% [markdown]
#  We set the <b>power usage file</b> earlier (though not on screen). Executing the variable name in a cell shows the file path and name.

# %%
power_avg_file
# Out:
# '/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/20141019_224335_P1A-P2B-P3C-P4D/power_avg.out'

# %% [markdown]
# Now we read it in by creating an instance of the <b>powertable</b> class.

# %%
power_usage = epys.powertable(power_avg_file)
# Out:
# 13 redundant lines removed

# %% [markdown]
# Note the printed result of the import process...

# %% [markdown]
# <img src="images/remove_redundant_plot_3.png">

# %% [markdown]
# Output is at regular time intervals and at small timesteps, often, there is little change.

# %% [markdown]
# <img src="images/remove_redundant_plot_4.png">

# %% [markdown]
# As part of the read-in process <b>epys</b> checks for, and if possible removes, rendundant data points.

# %% [markdown]
# The resulting powertable consists of 2 parts
# - a <b>dataframe</b> containing the data proper and
# - a <b>header</b> containing a dictionary of data parsed (as best can be done) from the commented lines at the start of the input file.
#
# We can examine the start or "head" of the dataframe using the head method.

# %%
power_usage.head()
# Out:
#              Total  ANTENNA  SSMM   BELA    ISA  MERMAG  MERTIS  MGNS  MORE  \
# Date
# 2024-05-07   18.35        0     0  13.47   0.00    4.88     0.0     0     0
# 2024-05-08  260.34       97     0  43.90  12.87    4.88    12.9     5     0
# 2024-05-09  260.34       97     0  43.90  12.87    4.88    12.9     5     0
# 2024-05-10  245.64       97     0  43.90  12.87    4.88     9.0     5     0
# 2024-05-11  202.82       97     0  13.47  12.87    4.88     9.0     5     0
#
#             PHEBUS  SERENA  SIMBIOSYS-STC  SIMBIOSYS-HRIC  SIMBIOSYS-VIHI  \
# Date
# 2024-05-07       0     0.0           0.00               0            0.00
# 2024-05-08       0    37.2           6.18               0           11.21
# 2024-05-09       0    37.2           6.18               0           11.21
# 2024-05-10      24     2.4           6.18               0           11.21
# 2024-05-11       0    34.3           0.00               0            0.00
#
#             MIXS-SIXS
# Date
# 2024-05-07        0.0
# 2024-05-08       29.2
# 2024-05-09       29.2
# 2024-05-10       29.2
# 2024-05-11       26.3

# %% [markdown]
# And we can look at the start of the header...

# %%
power_usage.header
# Out:
# {'CFG Template': 'v3.19',
#  'EDF Template': 'v3.12',
#  'EPS Version': 'v2.5.8',
#  'EVF (ESOC FD)': 'DDID appendix-H v2.1',
#  'EVF Template': 'v3.1',
#  'File Contents': 'Average Power Values',
#  'Generation Time': '19-October-2014_20',
#  'ITL Template': 'v3.10',
#  'Input CFG': '/Users/jmcaulif/Code/bepic/DATA/CONFIG/eps_mac.cfg',
#  'Input EDF': 'bepi.edf',
#  'Input EVF': '/Users/jmcaulif/Code/bepic/DATA/OGS/BC_SOA2013_P1A-P2B-P3C-P4D.evf',
#  'Input Timeline': '/Users/jmcaulif/Code/bepic/DATA/ITL/BC_SOA2013_P1A-P2B-P3C-P4D.itl',
#  'MDB version': 'SISBCETB "ETB (1, 0, 38)"',
#  'Output Filename': 'power_avg.out',
#  'POR Definition': 'CRID issue C4',
#  'Reference Date': datetime.datetime(2024, 5, 7, 0, 0),
#  'experiments': ['ANTENNA',
#   'SSMM',
#   'BELA',
#   'ISA',
#   'MERMAG',
#   'MERTIS',
#   'MGNS',
#   'MORE',
#   'PHEBUS',
#   'SERENA',
#   'SIMBIOSYS-STC',
#   'SIMBIOSYS-HRIC',
#   'SIMBIOSYS-VIHI',
#   'MIXS-SIXS'],
#  'headings': ['Elapsed time',
#   'Total',
#   'ANTENNA',
#   'SSMM',
#   'BELA',
#   'ISA',
#   'MERMAG',
#   'MERTIS',
#   'MGNS',
#   'MORE',
#   'PHEBUS',
#   'SERENA',
#   'SIMBIOSYS-STC',
#   'SIMBIOSYS-HRIC',
#   'SIMBIOSYS-VIHI',
#   'MIXS-SIXS'],
#  'len': 27,
#  'units': ['ddd_hh:mm:ss',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts',
#   'Watts']}

# %% [markdown]
# Or query some part of its dictionary object by passing it a key

# %%
power_usage.header['experiments']
# Out:
# ['ANTENNA',
#  'SSMM',
#  'BELA',
#  'ISA',
#  'MERMAG',
#  'MERTIS',
#  'MGNS',
#  'MORE',
#  'PHEBUS',
#  'SERENA',
#  'SIMBIOSYS-STC',
#  'SIMBIOSYS-HRIC',
#  'SIMBIOSYS-VIHI',
#  'MIXS-SIXS']

# %% [markdown]
# We now import the <b>power budget file</b> as an instance of the base epstable class. And manually assign the data column a heading.

# %%
power_budget = epys.epstable(power_budget_file)

# %%
power_budget.data.columns = ['Available']

# %%
power_budget.head()
# Out:
#                      Available
# date
# 2024-03-24 05:00:00        333
# 2024-03-25 01:18:00        387
# 2024-03-25 22:18:00        431
# 2024-03-26 19:48:00        506
# 2024-03-27 18:18:00        562

# %% [markdown]
# Now we merge the power budget data into the power usage datatable using the <b>join</b> method.
#
# We specify the <b>in_place</b> flag to have the changes made directly in the power usage table rather than returning a new, updated instance of the table.
#
# For experimenting, the latter is probably the better option.

# %%
power_usage.join(power_budget, in_place=True)
# Out:
# Warning: can only sort by level with a hierarchical index.

# %%
power_usage.head()
# Out:
#             Available   Total  ANTENNA  SSMM   BELA    ISA  MERMAG  MERTIS  \
# 2024-05-07        387   18.35        0     0  13.47   0.00    4.88     0.0
# 2024-05-08        495  260.34       97     0  43.90  12.87    4.88    12.9
# 2024-05-09        495  260.34       97     0  43.90  12.87    4.88    12.9
# 2024-05-10        495  245.64       97     0  43.90  12.87    4.88     9.0
# 2024-05-11        495  202.82       97     0  13.47  12.87    4.88     9.0
#
#             MGNS  MORE  PHEBUS  SERENA  SIMBIOSYS-STC  SIMBIOSYS-HRIC  \
# 2024-05-07     0     0       0     0.0           0.00               0
# 2024-05-08     5     0       0    37.2           6.18               0
# 2024-05-09     5     0       0    37.2           6.18               0
# 2024-05-10     5     0      24     2.4           6.18               0
# 2024-05-11     5     0       0    34.3           0.00               0
#
#             SIMBIOSYS-VIHI  MIXS-SIXS
# 2024-05-07            0.00        0.0
# 2024-05-08           11.21       29.2
# 2024-05-09           11.21       29.2
# 2024-05-10           11.21       29.2
# 2024-05-11            0.00       26.3

# %% [markdown]
# ## Plotting

# %% [markdown]
# The common python plotting library is <b>Matplotlib</b>. It is powerful and flexible and has for a long time been the main python plotting library.

# %%
power_usage.data[['Available', 'Total', 'MERTIS']].plot(title='Matplot Plotting Demo', grid=True)

# %% [markdown]
# We can slice the data and spread the results across a number of subplots.

# %%
power_usage.data[['Available', 'Total', 'MERTIS']].plot(title='Matplot Plotting Demo', grid=True, subplots=True)

# %% [markdown]
# The <b>STATIC</b> possibilities are endless...

# %%
power_usage.data.plot(title='Matplot Plotting Demo', grid=True, subplots=True)

# %% [markdown]
# ### Plot.ly

# %% [markdown]
# However, for increased interactivity, trace value flags and responsive zooming I'm using the Plotly online plotting library.
#
# <b>epys</b> has a simple yet flexible plotting API. You just have to run the <b>iplot</b> method on the <b>datatable object</b>  you want to plot.

# %%
power_usage.iplot()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~johnnycakes79/682" height="525" width="100%"></iframe>

# %% [markdown]
# Plot.ly does have some limitiation in the number of points it can plot and work with.
#
# This is due mainly to the fact that the data is processed on the Plot.ly servers and they don't want people sending Gbits of data and crashing their system.
#
# It can howerver deal with streaming data and that could be used to represent - as needed - larger data sets.
#
# There are alternatives to Plot.ly.
#
# Bokeh is an upcoming challenger. Google it to be impressed...
#
# But for what we are doing now, and compared to where we were before, <b>Plot.ly</b> is "nice".

# %% [markdown]
# ### Prototyping

# %% [markdown]
# One of the great advantages of the Notebook is in prototyping code.
#
# You can start by running each command in a single, isolated cell; later group the commands together in the functions within the Notebook; and if everything works as you expect later move the functions into external importable libraries.

# %% [markdown]
# Define Perihelion Seasons based on the power restrictions. We do this manually here but it could be easily built from the power budget file.

# %%
# these ranges are 1 day (each end) bigger than the power restricted periods.
perihelia = {'1' : (dt( 2024,  6,  1, 19, 18), dt( 2024,  6, 25, 17, 18)),
                   '2' : (dt( 2024,  8, 28, 18, 18), dt( 2024,  9, 21, 16, 48)),
                   '3' : (dt( 2024, 11, 24, 17, 48), dt( 2024, 12, 18, 15, 48)),
                   '4' : (dt( 2025,  2, 21, 16, 48), dt( 2025,  3, 17, 15, 18)),
                   '5' : (dt( 2025,  5, 19, 16, 18), dt( 2025,  6,  9, 21, 18))}

# %% [markdown]
# Define a mini-function for plotting the perihelia only.

# %%
def periplot(perihelion):
    power_usage.iplot(limits = perihelia[str(perihelion)], 
                                  y_title='Power [W]', 
                                  title='MPO Available Power and Instrument Consumption<br>Perhelion {}'.format(str(perihelion)))

# %% [markdown]
# Here's a close-up of the power situation around <b>Perihelion 1: 2024-6-1, 19:18 <u>to</u> 2024-6-25, 17:18</b>

# %%
periplot(1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~johnnycakes79/683" height="525" width="100%"></iframe>

# %%
power_usage.select(['Available', 'ANTENNA']).iplot(limits = perihelia['2'], y_title='Power [W]', title='MPO Available Power and Antenna Consumption<br>Perhelion 2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~johnnycakes79/684" height="525" width="100%"></iframe>

# %% [markdown]
# Of course you can only plot seasons you have data for...

# %%
periplot(5)
# Out:
# OOOPS: Your requested range appears to be outside the range of the data set:
# data set > 2024-05-07 00:00:00 to 2025-05-07 00:00:00
# limits     > 2025-05-19 16:18:00 to 2025-06-09 21:18:00

# %% [markdown]
# ### Save the Table Objects

# %% [markdown]
# In Python objects can be saved 'as-are' using something called "pickling".

# %%
pickle.dump( power_usage, open( "pickles/power_usage.p", "wb" ) )

# %% [markdown]
# Pickling saves the object in a compressed  semi-binary format that can later be <b>quickly</b> re-loaded.
#
# If we do a test to see how long this reload takes compared to the original reading-in of the file...

# %%
# %timeit test_df = pickle.load( open( "power_usage.p", "rb" ) )

# %%
# %timeit test_df2 = epys.powertable(power_avg_file)

# %% [markdown]
# While the difference for small, low-res simulation is small... we see the difference for these large, hi-res files is a factor of 25...
#
# ... and remember that the re-loaded pickle will include any post-processing done on the original dataframe, such as merging it with the power budget data.

# %% [markdown]
# ## Data Rate Analysis

# %% [markdown]
# <p>To read the average data rate file output by EPS we define an instance of the <b>datatable</b> class.</p>

# %%
data_rate_avg = epys.datatable(data_rate_avg_file)

# %% [markdown]
# If we look at the head of the resulting dataframe we see some characteristics that were not present in the power table.

# %% [markdown]
# It has multi-level index. And an additional column showing the data volume per timestep has been generated for each instrument.

# %%
data_rate_avg.head()

# %% [markdown]
# This dataframe shows what was used by the instruments during the simulation but we would like to compare this to the available power.

# %% [markdown]
# So we read in the downlink budget file by defining an instance of the top-level <b>epstable</b> class.

# %%
downlink_budget = epys.epstable(downlink_budget_file)

# %% [markdown]
# If we look at the head of this downlink budget table we can see that the column headings are not very informative.
#
# This is because there is no standard heading format for the downlink budget file.

# %%
downlink_budget.head()

# %% [markdown]
# When we read in the file, the epstable read method created a header attribute as well as the data attribute seen above, and this we can examine.

# %%
downlink_budget.header

# %% [markdown]
# This header, because it is not standard, is not as informative as that of the data rate table, but it does have a 'Data Columns' entry and this we can parse and use to build a mutli-level index for the downlink budget table.

# %%
channels = downlink_budget.header['Data Columns'].split()

# %%
arrays = [channels, ['Downlink' for x in channels], ['kbit/s' for x in channels]]

# %%
arrays

# %%
downlink_budget.data.columns = pd.MultiIndex.from_arrays(arrays, names=('channel', 'type', 'unit'))

# %% [markdown]
# We now have a budget dataframe with a mutli-level index.

# %%
downlink_budget.head()

# %% [markdown]
# We now want to join this budget data to the data rate datatable and we do this with the <b>join</b> method on the <b>data_rate_avg</b> object.

# %%
data_rate_avg.join(downlink_budget, in_place=True)

# %%
data_rate_avg.head()

# %% [markdown]
# Save datatable to pickle object

# %%
pickle.dump( data_rate_avg, open( "data_rate_avg_all_on_small.p", "wb" ) )

# %% [markdown]
# Let's plot the data rate data... all of it. We'll turn off the legend because it's very big and not really needed as we will see.

# %%
data_rate_avg.iplot(showlegend=False)

# %% [markdown]
# ## Slicing and Sub-Selection

# %% [markdown]
# You may not always want to examine or plot all of the data.

# %%
data_rate_avg.head()

# %%
data_rate_avg.select(('CeX', 'CeK', 'BELA','MERTIS'), ('Volume', 'Downlink'), None).head()

# %% [markdown]
# The slicing is "semi-clever"...

# %%
data_rate_avg.select(('CeX', 'CeK', 'BELA','MERTIS'), ('Volume', 'Downlink'), None).iplot(showlegend=False)

# %% [markdown]
# The software recognises the different data types (volume, rates) and splits the data across multiple axes as needed.
#
# More than 2 axes is also possible but I haven't seen a practical need for it ... yet!

# %% [markdown]
# ## Simulation Comparison

# %% [markdown]
# Now we can have a look at some real analytical ability - comparing the changes from one modelled scenario to another.
#
# We'll start by importing previously saved sample data from pickles.

# %%
all_on = pickle.load( open( "data_rate_avg.p", "rb" ) )

# %%
four_scenarios = pickle.load( open( "4_scenarios.p", "rb" ) )

# %%
all_on.select('MERTIS', 'Accum', None).tail()

# %%
four_scenarios.select('MERTIS', 'Accum', None).tail()

# %%
mertis_all_on = all_on.select(('MERTIS'), 'Volume', None)
mertis_4_scenarios = four_scenarios.select(('MERTIS'), 'Volume', None)

# %%
mertis_all_on.iplot()

# %%
mertis_4_scenarios.iplot()

# %% [markdown]
# <b>epys</b> datatables can be subtracted from one another... provided (for now) that it makes sense to do so, i.e. if the column titles, number and length are the same.

# %%
mertis_diff = mertis_4_scenarios.sub(mertis_all_on)

# %%
mertis_diff.iplot()

# %% [markdown]
# And it can be very useful and informative to do this for all instruments when jumping from one scenario simulation to another.

# %%
all_diff = all_on.sub(four_scenarios)

# %%
all_diff.select(None, 'Volume', None).iplot()

# %% [markdown]
# ## Some more interaction...

# %% [markdown]
# A "silly" example...
# <blockquote>
# We see the downlink goes to zero for a period of time and we would like to see the planetary constellation in this period.
# </blockquote>

# %%
data_rate_avg.iplot(limits = perihelia['1'], showlegend=False)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~johnnycakes79/687" height="525" width="100%"></iframe>

# %% [markdown]
# We define a list (technically a tuple) of dates around the "blackout" period.

# %%
dates = ("2024-Jun-09", "2024-Jun-10", "2024-Jun-11", "2024-Jun-12", "2024-Jun-13", 
              "2024-Jun-14", "2024-Jun-15", "2024-Jun-16", "2024-Jun-17", "2024-Jun-18")

# %%
dates = ("2024-Dec-03", "2024-Dec-04", "2024-Dec-05", "2024-Dec-06", "2024-Dec-07")

# %%
dates = [ x.strftime("%Y-%B-%d %H:%M:%S") for x in data_rate_avg.data.index.tolist()]

# %% [markdown]
# And we send this list to the <b>epys</b> module <b>planetsplot</b>, which uses SPICE to compute the planet positions.

# %%
orbit_plots = epys.planetsplot(userdates=dates)

# %% [markdown]
# This returns a list of orbit constellation plots.

# %% [markdown]
# And this list can be fed into a simple display function.

# %% [markdown]
# ## Example

# %%
@interact(step=(0,len(orbit_plots)-1))
def orbit(step):
    display.display(SVG(filename=orbit_plots[step]))

# %% [markdown]
# ## More soon ...

# %% [markdown]
# <img style="float: right; height: 100px; margin: 0px 0px 0px;" src="http://www.rssd.esa.int/SB/BEPICOLOMBO/images/bepi-logo.png">
# <img style="float: left; height: 100px; margin: 0px 0px 0px 0px;" src="http://cdn-www.xda-developers.com/wp-content/uploads/2013/12/python.png">
# <img style="" src="http://nbviewer.ipython.org/github/ipython/ipython/blob/master/examples/images/ipython_logo.png">

# %% [markdown]
# <blockquote>
# <p style="text-align: right;">
# “Always code as if the guy who ends up maintaining your code will be a violent psychopath who knows where you live.”<br>
#  - Martin Golding
#  </p>
# </blockquote>

# %% [markdown]
# ## Todo

# %% [markdown]
# - when merging or slicing the dataframes the header info doesn't get up dated... fix this.
# - plot multiple scenarios or traces on different sub-plots with sync'ed zoom.

# %%
multiaxiszoom()

# %% [markdown]
# ## Scratch Pad

# %%
def multiaxiszoom():
    trace1 = Scatter(
        x=[0, 1, 2],
        y=[10, 11, 12]
    )
    trace2 = Scatter(
        x=[2, 3, 4],
        y=[100, 110, 120],
        yaxis='y2'
    )
    trace3 = Scatter(
        x=[3, 4, 5],
        y=[1000, 1100, 1200],
        yaxis='y3'
    )
    data = Data([trace1, trace2, trace3])
    layout = Layout(
        yaxis=YAxis(
            domain=[0, 0.30]
        ),
        legend=Legend(
            traceorder='reversed'
        ),
        yaxis2=YAxis(
            domain=[0.33, 0.63]
        ),
        yaxis3=YAxis(
            domain=[0.66, 0.96]
        )
    )
    fig = Figure(data=data, layout=layout)

    py.iplot(fig)

# %%
test = pd.read_csv('/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/mapps_datapack.csv', skiprows=22, header=[0,1])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-60-fb899f5b6e1f> in <module>()
# ----> 1 test = pd.read_csv('/Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/mapps_datapack.csv', skiprows=22, header=[0,1])
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:2966)()
#
# /Users/jmcaulif/.virtualenvs/epys/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5328)()
#
# IOError: File /Users/jmcaulif/Code/bepic/OUTPUT/SIMULATION DATA/mapps_datapack.csv does not exist

# %%
test.shape

# %%
pickle.dump( test, open( "datapack_info.p", "wb" ) )
